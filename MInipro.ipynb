# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('city_day.csv')

# %%
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
X=df.tail(500)

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
Z=pd.DataFrame(X)

# %%
Z.isnull()
# Out:
#         City   Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 29031  False  False  False  False  False  False  False  False  False  False
# 29032  False  False  False  False  False  False  False  False  False  False
# 29033  False  False  False  False  False  False  False  False  False  False
# 29034  False  False  False  False  False  False  False  False  False  False
# 29035  False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 29526  False  False  False  False  False  False  False  False  False  False
# 29527  False  False  False  False  False  False  False  False  False  False
# 29528  False  False  False  False  False  False  False  False  False  False
# 29529  False  False  False  False  False  False  False  False  False  False
# 29530  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
Z.isnull().sum()
# Out:
# City           0
# Date           0
# PM2.5         13
# PM10          21
# NO            12
# NO2           12
# NOx           12
# NH3           19
# CO            12
# SO2           12
# O3            12
# Benzene       13
# Toluene       13
# Xylene        13
# AQI           29
# AQI_Bucket    29
# dtype: int64

# %%
Z
# Out:
#                 City        Date  PM2.5    PM10     NO    NO2    NOx    NH3  \
# 29031  Visakhapatnam  2019-02-18  51.74  100.88  12.68  37.14  30.07   8.91
# 29032  Visakhapatnam  2019-02-19  33.27   71.67   6.19  20.37  15.87   8.37
# 29033  Visakhapatnam  2019-02-20  39.61   86.76  17.41  24.55  27.22   8.72
# 29034  Visakhapatnam  2019-02-21  51.81  115.70  24.02  36.12  38.74   9.88
# 29035  Visakhapatnam  2019-02-22  52.80  118.58  10.35  40.23  29.58  10.50
# ...              ...         ...    ...     ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02   50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00   66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
Z.fillna(0)
# Out:
#                 City        Date  PM2.5    PM10     NO    NO2    NOx    NH3  \
# 29031  Visakhapatnam  2019-02-18  51.74  100.88  12.68  37.14  30.07   8.91
# 29032  Visakhapatnam  2019-02-19  33.27   71.67   6.19  20.37  15.87   8.37
# 29033  Visakhapatnam  2019-02-20  39.61   86.76  17.41  24.55  27.22   8.72
# 29034  Visakhapatnam  2019-02-21  51.81  115.70  24.02  36.12  38.74   9.88
# 29035  Visakhapatnam  2019-02-22  52.80  118.58  10.35  40.23  29.58  10.50
# ...              ...         ...    ...     ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02   50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00   66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
Z.drop_duplicates()
# Out:
#                 City        Date  PM2.5    PM10     NO    NO2    NOx    NH3  \
# 29031  Visakhapatnam  2019-02-18  51.74  100.88  12.68  37.14  30.07   8.91
# 29032  Visakhapatnam  2019-02-19  33.27   71.67   6.19  20.37  15.87   8.37
# 29033  Visakhapatnam  2019-02-20  39.61   86.76  17.41  24.55  27.22   8.72
# 29034  Visakhapatnam  2019-02-21  51.81  115.70  24.02  36.12  38.74   9.88
# 29035  Visakhapatnam  2019-02-22  52.80  118.58  10.35  40.23  29.58  10.50
# ...              ...         ...    ...     ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02   50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00   66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
dropped_=Z.dropna()

# %%
dropped_.describe()
# Out:
#             PM2.5        PM10          NO         NO2         NOx         NH3  \
# count  451.000000  451.000000  451.000000  451.000000  451.000000  451.000000
# mean    35.868271   94.921752   10.648492   33.179424   26.191996    9.848914
# std     21.074417   41.483145    9.748709   12.166748   12.179844    6.005086
# min      2.000000    8.160000    0.730000    4.130000    6.020000    1.130000
# 25%     22.260000   66.370000    3.255000   24.205000   17.245000    6.310000
# 50%     31.250000   92.400000    8.190000   32.490000   24.760000    9.030000
# 75%     44.705000  115.420000   14.575000   40.820000   32.060000   11.755000
# max    177.200000  326.400000   90.840000   85.930000   89.980000   43.250000
#
#                CO         SO2          O3     Benzene     Toluene      Xylene  \
# count  451.000000  451.000000  451.000000  451.000000  451.000000  451.000000
# mean     0.744235   10.864146   27.023592    3.741220    9.007384    2.149357
# ...

# %%
Z.shape
# Out:
# (500, 16)

# %%
Z.drop_duplicates()
# Out:
#                 City        Date  PM2.5    PM10     NO    NO2    NOx    NH3  \
# 29031  Visakhapatnam  2019-02-18  51.74  100.88  12.68  37.14  30.07   8.91
# 29032  Visakhapatnam  2019-02-19  33.27   71.67   6.19  20.37  15.87   8.37
# 29033  Visakhapatnam  2019-02-20  39.61   86.76  17.41  24.55  27.22   8.72
# 29034  Visakhapatnam  2019-02-21  51.81  115.70  24.02  36.12  38.74   9.88
# 29035  Visakhapatnam  2019-02-22  52.80  118.58  10.35  40.23  29.58  10.50
# ...              ...         ...    ...     ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02   50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00   66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
dropped_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 451 entries, 29031 to 29529
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        451 non-null    object
#  1   Date        451 non-null    object
#  2   PM2.5       451 non-null    float64
#  3   PM10        451 non-null    float64
#  4   NO          451 non-null    float64
#  5   NO2         451 non-null    float64
#  6   NOx         451 non-null    float64
#  7   NH3         451 non-null    float64
#  8   CO          451 non-null    float64
#  9   SO2         451 non-null    float64
#  10  O3          451 non-null    float64
#  11  Benzene     451 non-null    float64
#  12  Toluene     451 non-null    float64
#  13  Xylene      451 non-null    float64
#  14  AQI         451 non-null    float64
#  15  AQI_Bucket  451 non-null    object
# dtypes: float64(13), object(3)
# memory usage: 59.9+ KB

# %%
x=Z["NO2"]
y=Z["SO2"]
plt.scatter(x,y,color="Green")
plt.xlabel("NO2",color='skyblue')
plt.ylabel("SO2",color='yellow')
plt.title("Scatter plot between Two Major Airpollutants")
plt.grid(True)
plt.show()

# %%
sns.pairplot(Z)

# %%
x1=Z.iloc[:,2:-1]

# %%
x1
# Out:
#        PM2.5    PM10     NO    NO2    NOx    NH3    CO    SO2     O3  Benzene  \
# 29031  51.74  100.88  12.68  37.14  30.07   8.91  0.79  20.80  17.83     1.90
# 29032  33.27   71.67   6.19  20.37  15.87   8.37  0.68   4.56  15.31     1.43
# 29033  39.61   86.76  17.41  24.55  27.22   8.72  0.72   5.77  13.42     1.92
# 29034  51.81  115.70  24.02  36.12  38.74   9.88  0.83  15.92  17.11     2.06
# 29035  52.80  118.58  10.35  40.23  29.58  10.50  0.67  10.17  28.71     1.87
# ...      ...     ...    ...    ...    ...    ...   ...    ...    ...      ...
# 29526  15.02   50.94   7.68  25.06  19.54  12.47  0.47   8.55  23.30     2.24
# 29527  24.38   74.09   3.42  26.06  16.53  11.99  0.52  12.72  30.14     0.74
# 29528  22.91   65.73   3.45  29.53  18.33  10.71  0.48   8.42  30.96     0.01
# 29529  16.64   49.97   4.05  29.26  18.80  10.03  0.52   9.84  28.30     0.00
# 29530  15.00   66.00   0.40  26.85  14.05   5.20  0.59   2.10  17.05      NaN
#
#        Toluene  Xylene    AQI
# ...

# %%
x1.corr()
# Out:
#             PM2.5      PM10        NO       NO2       NOx       NH3        CO  \
# PM2.5    1.000000  0.816252  0.078133  0.448588  0.292381  0.312078  0.627891
# PM10     0.816252  1.000000  0.213346  0.530325  0.422410  0.301457  0.569158
# NO       0.078133  0.213346  1.000000  0.440054  0.876193 -0.046491  0.319033
# NO2      0.448588  0.530325  0.440054  1.000000  0.817097  0.051006  0.453277
# NOx      0.292381  0.422410  0.876193  0.817097  1.000000 -0.003558  0.447489
# NH3      0.312078  0.301457 -0.046491  0.051006 -0.003558  1.000000  0.185422
# CO       0.627891  0.569158  0.319033  0.453277  0.447489  0.185422  1.000000
# SO2      0.046501  0.041532  0.279773  0.245562  0.309640 -0.186377  0.100853
# O3       0.542648  0.195176 -0.294209  0.004003 -0.183200  0.181867  0.215990
# Benzene  0.444455  0.464922  0.391487  0.550985  0.546511 -0.012413  0.537959
# Toluene  0.232918  0.214987  0.344070  0.456235  0.464026 -0.033375  0.362674
# ...

# %%
plt.figure(figsize=(8, 6))
sns.histplot(Z['NO2'])
plt.title('Histogram of NO2')
plt.xlabel('NO2test')
plt.ylabel('NO2Predicted')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(Z['SO2'])
plt.title('Histogram of SO2')
plt.xlabel('SO2test')
plt.ylabel('SO2Predicted')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(x1.corr())
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='NO2', y='SO2', data=df)
plt.title('Scatter Plot of NO2 vs SO2')
plt.xlabel('NO2')
plt.ylabel('SO2')
plt.show()

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: C:\Users\91889\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
